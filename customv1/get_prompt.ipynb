# %%
import os
import openai
import pprint
import logging
import time

# %%
openai.api_key = "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"

# %%
# openai.Model.list()

# %%
def retrieve_text_pair(text):
    descriptions = []
    commands = []
    for line in text.split("\n"):
        line = line.split(":")
        if "Description" in line:
            descriptions.append(':'.join(line[1:]))
        elif "Command" in line:
            commands.append(':'.join(line[1:]))
        else:
            pass
    valid_len = min(len(descriptions), len(commands)) - 1
    return descriptions[:valid_len], commands[:valid_len]

# text_pair = retrieve_text_pair(text)
# text_pair

# %%
def write_to_file(text_pair, description_path, command_path):
    description_file = open(description_path, 'a')
    command_file = open(command_path, 'a')
    for d, c in zip(text_pair[0], text_pair[1]): 
        description_file.write(d.strip()+'\n')
        command_file.write(c.strip()+'\n')
    description_file.close()
    command_file.close()

# write_to_file(text_pair, "output_description.txt", "output_command.txt")

# %%
def get_response(description, command):
    prompt = \
    f"""Generate 10 differnt bash commands and corresponding description:

Description: {description}
Command: {command}
"""

    response = openai.Completion.create(
    engine="code-davinci-002",
    prompt=prompt,
    temperature=0.0,
    max_tokens=256,
    top_p=1.0,
    frequency_penalty=0.0,
    presence_penalty=0.2
    )
    return response.choices[0]["text"]

# %%
def read_input_and_process(start_index, input_description, input_command):
    description_file = open(input_description, 'r', encoding="utf8")
    command_file = open(input_command, 'r', encoding="utf8")
    description_list = description_file.readlines()
    command_list = command_file.readlines()
    description_file.close()
    command_file.close()
    for i, (des, com) in enumerate(zip(description_list, command_list)):
        if i < start_index:
            continue
        try:
            print(i, des.strip(), com.strip())
            logging.info("running line: ",i)
            text = get_response(des, com)
            text_pair = retrieve_text_pair(text)
            write_to_file(text_pair, "output_description.txt", "output_command.txt")
            time.sleep(5)
        except Exception as e:
            logging.warn(i, "error: ", str(e))


read_input_and_process(180, "user_input.txt", "commands.txt")
# Out:
# 180 Set the write permission on the file 'filename'. chmod w filename
# 181 Give execute permissions to the file named 'filename'. chmod x filename
# 182 Allow the file 'filename' to be executed. chmod x filename
# 183 Make the file 'filename' executable. chmod x filename
# 184 Set the file 'filename' so it can be run. chmod x filename
# 185 Grant execute rights to the file 'filename'. chmod x filename
# 186 Remove write permission from the file 'filename' chmod -= filename
# 187 Revoke write access to 'filename' chmod -= filename
# 188 Take away the write ability for 'filename' chmod -= filename
# 189 Deny write permission for the file 'filename' chmod -= filename
# 190 Withdraw write access to the file 'filename' chmod -= filename
# 191 For changing the ownership of a file/directory Chown user
# 192 Change the ownership of the file to the specified user. Chown user
# 193 Assign the file to a new owner, the user specified. Chown user
# 194 Make the user the new owner of the file. Chown user
# 195 Transfer the ownership of the file to the named user. Chown user
# 196 Alter the ownership of the file so that it belongs to the specified user. Chown user
# 197 change the user as well as group for a file or directory Chown user:group filename
# 198 Assign a new owner to a file or directory Chown user:group filename
# 199 Transfer ownership of a file or directory to a specified user Chown user:group filename
# 200 Reassign ownership of a file or directory to a user Chown user:group filename
# 201 Make a user the owner of a file or directory Chown user:group filename
# 202 Specify a new owner for a file or directory Chown user:group filename
# 203 Set a user as the owner of a file or directory Chown user:group filename
# 204 Display the value of a variable echo $VARIABLE
# 205 Show the contents of a variable echo $VARIABLE
# 206 Print the value stored in a variable echo $VARIABLE
# 207 Output the contents of a variable echo $VARIABLE
# 208 Reveal the contents stored in a variable echo $VARIABLE
# 209 Present the value of a variable. echo $VARIABLE
# 210 Show the environment variables env
# 211 Display the current environment settings env
# 212 Print the shell environment information env
# 213 Present the environment configurations env
# 214 Reveal the system environment variables env
# 215 Output the environment variables of the current shell session. env
# 216 Create a new variable VARIABLE_NAME= variable_value
# 217 Define a new variable and set its value VARIABLE_NAME= variable_value
# 218 Establish a new variable and give it a value VARIABLE_NAME= variable_value
# C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py:19: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(i, "error: ", str(e))
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 14, in read_input_and_process
#     text = get_response(des, com)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\4134653161.py", line 9, in get_response
#     response = openai.Completion.create(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 227, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 620, in _interpret_response
#     self._interpret_response_line(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 680, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 1906, in _run_once
#     handle._run()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\ipkernel.py", line 423, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 2945, in run_cell
#     result = self._run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3000, in _run_cell
#     return runner(coro)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3203, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3382, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 22, in <module>
#     read_input_and_process(180, "user_input.txt", "commands.txt")
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 19, in read_input_and_process
#     logging.warn(i, "error: ", str(e))
# Message: 217
# Arguments: ('error: ', 'Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.')
# 219 Declare a new variable and assign it a value VARIABLE_NAME= variable_value
# 220 Make a new variable and specify its value VARIABLE_NAME= variable_value
# 221 Form a new variable and provide it with a value. VARIABLE_NAME= variable_value
# 222 Remove a variable Unset
# 223 Remove a variable Unset
# 224 Delete a variable Unset
# 225 Eliminate a variable Unset
# 226 Undeclare a variable Unset
# 227 Nullify a variable Unset
# 228 Dispose of a variable. Unset
# 229 To set value of an environment variable export Variable=value
# 230 Assign the value "value" to a variable export Variable=value
# 231 Define a variable with the value "value" export Variable=value
# 232 Establish a variable with the value "value" export Variable=value
# 233 Specify a variable and its value "value" export Variable=value
# 234 Set a variable to the value "value" export Variable=value
# 235 Create a variable and give it the value "value" export Variable=value
# 236 Add a new user  of 'username' sudo adduser username
# 237 Create a new  of 'username'  user with administrative privileges sudo adduser username
# 238 Add a new  of 'username' user with root permissions sudo adduser username
# 239 Establish a new user  of 'username' with superuser access sudo adduser username
# 240 Grant root privileges to a new user  of 'username' sudo adduser username
# 241 Create a new administrative user  of 'username' sudo adduser username
# 242 change the password of a user sudo passwd -l 'username'
# 243 Update a user's  of 'username' password sudo passwd -l 'username'
# 244 Modify a user's  of 'username' password sudo passwd -l 'username'
# 245 Reset a user's  of 'username' password sudo passwd -l 'username'
# 246 Alter a user's  of 'username' password sudo passwd -l 'username'
# 247 Change a user's  of 'username' password security. sudo passwd -l 'username'
# 248 Remove a newly created user of 'username' sudo userdel -r 'username'
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 14, in read_input_and_process
#     text = get_response(des, com)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\4134653161.py", line 9, in get_response
#     response = openai.Completion.create(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 227, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 620, in _interpret_response
#     self._interpret_response_line(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 680, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 1906, in _run_once
#     handle._run()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\ipkernel.py", line 423, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 2945, in run_cell
#     result = self._run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3000, in _run_cell
#     return runner(coro)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3203, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3382, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 22, in <module>
#     read_input_and_process(180, "user_input.txt", "commands.txt")
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 19, in read_input_and_process
#     logging.warn(i, "error: ", str(e))
# Message: 247
# Arguments: ('error: ', 'Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.')
# 249 Delete a user of 'username' and their related files sudo userdel -r 'username'
# 250 Remove a user  of 'username' and their associated data sudo userdel -r 'username'
# 251 Terminate a user  of 'username' and their belongings sudo userdel -r 'username'
# 252 Erase a user  of 'username' and their files permanently sudo userdel -r 'username'
# 253 Get rid of a user  of 'username' and their information sudo userdel -r 'username'
# 254 Purge a user  of 'username' and their related assets. sudo userdel -r 'username'
# 255 Assign a user of 'username' to an additional of "groupname" group sudo usermod -a -G GROUPNAME USERNAME
# 256 Add a user of 'username' to a secondary of "groupname" group sudo usermod -a -G GROUPNAME USERNAME
# 257 Grant a user of 'username' membership to another of "groupname" group sudo usermod -a -G GROUPNAME USERNAME
# 258 Make a user of 'username' part of an extra of "groupname" group sudo usermod -a -G GROUPNAME USERNAME
# 259 Give a user of 'username' access to an additional of "groupname" group sudo usermod -a -G GROUPNAME USERNAME
# 260 Include a user of 'username' in a supplementary of "groupname" group sudo usermod -a -G GROUPNAME USERNAME
# 261 Enroll a user of 'username' in an additional group of "groupname" membership sudo usermod -a -G GROUPNAME USERNAME
# 262 Add a user of 'username' to a supplementary group of "groupname" membership sudo usermod -a -G GROUPNAME USERNAME
# 263 To remove a user from a group sudo deluser USER GROUPNAME
# 264 Remove a user account and its association with a group. sudo deluser USER GROUPNAME
# 265 Delete a user account and their membership in a group. sudo deluser USER GROUPNAME
# 266 Unregister a user and their group affiliation. sudo deluser USER GROUPNAME
# 267 Eliminate a user and their connection to a group. sudo deluser USER GROUPNAME
# 268 Purge a user account and the group it belongs to. sudo deluser USER GROUPNAME
# 269 Shows information of all the users logged in finger
# 270 Display information about a user on a Unix-like system. finger
# 271 Show details about a specific user account. finger
# 272 Get information about a particular user on a Unix system. finger
# 273 Retrieve details about a user including login name, real name, and login time. finger
# 274 Fetch information about a user, such as their login name, full name, and last login time. finger
# 275 Gives information of a particular user finger username
# 276 Display information about the specified user. finger username
# 277 Show details about a specific user on the system. finger username
# 278 Retrieve information about a particular user. finger username
# 279 See information about the user with the specified username. finger username
# 280 Get information such as login time, real name, and home directory of a user. finger username
# 281 login into a remote Linux machine using SSH SSH username@ip-address
# 282 Connect to a remote computer using the SSH protocol with the specified username and IP address. SSH username@ip-address
# 283 Establish a secure shell connection to the remote machine using the given username and IP. SSH username@ip-address
# 284 Log in to a remote system through SSH with the provided username and IP address. SSH username@ip-address
# 285 Access a remote device over the internet securely with SSH and the specified username and IP. SSH username@ip-address
# 286 Initiate a secure shell session to a remote machine with the provided username and IP address. SSH username@ip-address
# 287 To ping and Analyzing network and host connections Ping hostname="sample_hostname"
# 288 Send a test message to the host named 'sample_hostname' to check its connectivity. Ping hostname="sample_hostname"
# 289 Check the reachability of 'sample_hostname' by sending a ping request. Ping hostname="sample_hostname"
# 290 Determine if 'sample_hostname' is reachable by sending a network test packet. Ping hostname="sample_hostname"
# 291 Verify the network connection to 'sample_hostname' by sending a ping. Ping hostname="sample_hostname"
# 292 Test the network connection to 'sample_hostname' by sending a network diagnostic packet. Ping hostname="sample_hostname"
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 14, in read_input_and_process
#     text = get_response(des, com)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\4134653161.py", line 9, in get_response
#     response = openai.Completion.create(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 227, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 620, in _interpret_response
#     self._interpret_response_line(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 680, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 1906, in _run_once
#     handle._run()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\ipkernel.py", line 423, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 2945, in run_cell
#     result = self._run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3000, in _run_cell
#     return runner(coro)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3203, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3382, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 22, in <module>
#     read_input_and_process(180, "user_input.txt", "commands.txt")
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 19, in read_input_and_process
#     logging.warn(i, "error: ", str(e))
# Message: 291
# Arguments: ('error: ', 'Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.')
# 293 Display files in the current directory of a remote computer dir
# 294 Show the contents of the current directory. dir
# 295 Display a list of files and subdirectories in the current folder. dir
# 296 List the items in the current working directory. dir
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 14, in read_input_and_process
#     text = get_response(des, com)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\4134653161.py", line 9, in get_response
#     response = openai.Completion.create(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 227, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 620, in _interpret_response
#     self._interpret_response_line(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 680, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 1906, in _run_once
#     handle._run()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\ipkernel.py", line 423, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 2945, in run_cell
#     result = self._run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3000, in _run_cell
#     return runner(coro)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3203, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3382, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 22, in <module>
#     read_input_and_process(180, "user_input.txt", "commands.txt")
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 19, in read_input_and_process
#     logging.warn(i, "error: ", str(e))
# Message: 295
# Arguments: ('error: ', 'Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.')
# 297 Examine the files and subdirectories present in the present location. dir
# 298 Provide an overview of the files and folders in the current directory. dir
# 299 change directory to “dirname” on a remote computer cd "dirname"
# 300 Change the current working directory to 'dirname'. cd "dirname"
# 301 Navigate to the directory named 'dirname'. cd "dirname"
# 302 Go to the folder 'dirname'. cd "dirname"
# 303 Enter the directory 'dirname'. cd "dirname"
# 304 Switch to the directory 'dirname'. cd "dirname"
# 305 upload ‘file’ from local to remote computer put file
# 306 Upload a file. put file
# 307 Send a file to a specified location. put file
# 308 Transfer a file from the current device to another. put file
# 309 Place a file into a designated directory. put file
# 310 Copy a file to a target location. put file
# 311 Download ‘file’ from remote to local computer get file
# 312 Retrieve a file. get file
# 313 Download a file. get file
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 14, in read_input_and_process
#     text = get_response(des, com)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\4134653161.py", line 9, in get_response
#     response = openai.Completion.create(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 227, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 620, in _interpret_response
#     self._interpret_response_line(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 680, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 1906, in _run_once
#     handle._run()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\ipkernel.py", line 423, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 2945, in run_cell
#     result = self._run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3000, in _run_cell
#     return runner(coro)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3203, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3382, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 22, in <module>
#     read_input_and_process(180, "user_input.txt", "commands.txt")
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 19, in read_input_and_process
#     logging.warn(i, "error: ", str(e))
# Message: 312
# Arguments: ('error: ', 'Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.')
# 314 Acquire a file. get file
# 315 Fetch a file. get file
# 316 Obtain a file. get file
# 317 Logout quit
# 318 Exit the terminal. quit
# 319 End the session. quit
# 320 Close the command prompt. quit
# 321 Terminate the command line interface. quit
# 322 Leave the command line interface and return to the previous interface. quit
# 323 To send a process to the background bg
# 324 Resume a stopped job in the background. bg
# 325 Move a suspended process to run in the background. bg
# 326 Start a job running in the background. bg
# 327 Continue execution of a stopped task in the background. bg
# 328 Make a previously stopped job run in the background. bg
# 329 To run a stopped process in the foreground fg
# 330 Bring a background process to the foreground. fg
# 331 Make a background job the active process. fg
# 332 Move a background task to the command line interface. fg
# 333 Resume a stopped process in the foreground. fg
# 334 Switch a background task to the forefront. fg
# 335 Details on all Active Processes top
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 14, in read_input_and_process
#     text = get_response(des, com)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\4134653161.py", line 9, in get_response
#     response = openai.Completion.create(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 227, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 620, in _interpret_response
#     self._interpret_response_line(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 680, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 1906, in _run_once
#     handle._run()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\ipkernel.py", line 423, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 2945, in run_cell
#     result = self._run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3000, in _run_cell
#     return runner(coro)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3203, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3382, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 22, in <module>
#     read_input_and_process(180, "user_input.txt", "commands.txt")
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 19, in read_input_and_process
#     logging.warn(i, "error: ", str(e))
# Message: 334
# Arguments: ('error: ', 'Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.')
# 336 Display the processes running on the system and their resource usage. top
# 337 Show the current status of system processes and their utilization of system resources. top
# 338 Monitor the performance of processes in real-time. top
# 339 View the active processes and their CPU, memory, and other resource usage statistics. top
# 340 Track the most resource-intensive processes running on the system in real-time. top
# 341 Give the status of processes running for a user ps
# 342 Show the current processes running on the system. ps
# 343 Display the list of active processes. ps
# 344 List the processes currently in execution. ps
# 345 Examine the tasks currently running on the system. ps
# 346 View the active processes on the system and their status. ps
# 347 Gives the status of a particular process ps PID
# 348 Show information about the process with the specified process ID (PID). ps PID
# 349 Display the details of the process identified by its PID. ps PID
# 350 List the attributes of the process with PID. ps PID
# 351 Examine the information of the process matching the PID provided. ps PID
# 352 Retrieve information about the process indicated by its PID value. ps PID
# 353 Gives the Process ID (PID) of a process pidof
# 354 Find the process ID of a running program. pidof
# 355 Get the identification number of a currently running process. pidof
# 356 Retrieve the process identifier of a specific application. pidof
# 357 Determine the process ID of a specified executable. pidof
# 358 Locate the process ID for a running software program. pidof
# 359 Kills a process kill PID
# 360 Terminate the process with the specified process ID (PID). kill PID
# 361 End the running task with the given PID number. kill PID
# 362 Send a signal to end the process identified by PID. kill PID
# 363 Stop the process with PID from running. kill PID
# 364 Forcefully close the process with the PID indicated. kill PID
# 365 Starts a process with a given priority nice
# 366 Set the priority of a process to run with lower CPU utilization. nice
# 367 Run a program with a lower priority than other processes. nice
# 368 Execute a command at a lower priority to allow other processes to have more CPU time. nice
# 369 Launch a process with reduced CPU resource allocation. nice
# 370 Start a command with a lower CPU allocation for better system performance. nice
# 371 Changes priority of an already running process renice
# 372 Adjust the priority level of a running process. renice
# 373 Change the scheduling priority of an active process. renice
# 374 Modify the priority value assigned to a process that is already running. renice
# 375 Alter the importance level of a process that is currently executing. renice
# 376 Redefine the priority of a process that is in operation. renice
# 377 Gives free hard disk space on your system df
# 378 Show the amount of free disk space on all mounted file systems. df
# 379 Display the available and used disk space on the system. df
# 380 Check the amount of space occupied and the space available on the file systems. df
# 381 See the disk space utilization of all mounted file systems. df
# 382 View the amount of storage used and the storage remaining on all mounted file systems. df
# 383 Gives free RAM on your system free
# 384 Display the amount of free and used memory in the system. free
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 14, in read_input_and_process
#     text = get_response(des, com)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\4134653161.py", line 9, in get_response
#     response = openai.Completion.create(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 227, in request
#     resp, got_stream = self._interpret_response(result, stream)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 620, in _interpret_response
#     self._interpret_response_line(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\openai\api_requestor.py", line 680, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.RateLimitError: Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\logging\__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\base_events.py", line 1906, in _run_once
#     handle._run()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\ipkernel.py", line 423, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 2945, in run_cell
#     result = self._run_cell(
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3000, in _run_cell
#     return runner(coro)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3203, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3382, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\sha\Desktop\NL2BASH simple\.conda\lib\site-packages\IPython\core\interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 22, in <module>
#     read_input_and_process(180, "user_input.txt", "commands.txt")
#   File "C:\Users\sha\AppData\Local\Temp\ipykernel_33648\1366258353.py", line 19, in read_input_and_process
#     logging.warn(i, "error: ", str(e))
# Message: 383
# Arguments: ('error: ', 'Rate limit reached for default-code-davinci-002 in organization org-DjQVqYz5nfmgxwIh0WLWNCrq on requests per min. Limit: 20.000000 / min. Current: 30.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.')
# 385 Show the available and used system memory information. free
# 386 List the amount of physical memory and swap memory that is unused. free
# 387 Print the memory usage statistics. free
# 388 Report the system's available and utilized memory resources. free
